# %% [markdown]
# <a href="https://colab.research.google.com/github/F-Abir/GEE-Python-API/blob/main/Anjani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input 1
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Input 2
a = 10
b = 5
print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)
# Out:
# Sum: 15
# Difference: 5
# Product: 50
# Division: 2.0

# %%
# Input 3
for i in range(1, 6):
    print("Number:", i)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5

# %%
# Input 4
def square(x):
    return x * x

print("Square of 7:", square(7))
# Out:
# Square of 7: 49

# %%
# Input 5
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print("I like", fruit)
# Out:
# I like apple
# I like banana
# I like cherry

# %%
# Input 6
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [n**2 for n in x]

plt.plot(x, y, marker='o')
plt.title("Square Numbers")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()
